# %% [markdown]
# ## Imports

# %%
## Plotly is not included in your dojo-env
# !pip install plotly

# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import os, json

## importing plotly 
import plotly.express as px

# %% [markdown]
# ## Load Data

# %%
hero_df = pd.read_csv('Data/superhero_info - superhero_info.csv')

# %%
hero_df.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}

# %%
powers_df = pd.read_csv('Data/superhero_powers - superhero_powers.csv')

# %%
powers_df.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %% [markdown]
# ## Clean Data

# %% [markdown]
# ### Split Hero|Publisher

# %%
hero_df['Hero|Publisher'].str.split('|', expand=True)
hero_df.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}

# %%
## save the 2 new columns into the dataframe
hero_df[['Hero','Publisher']] = hero_df['Hero|Publisher'].str.split('|',expand=True)
hero_df.head(2)
# Out:
#                  Hero|Publisher Gender           Race Alignment Hair color  \
# 0          A-Bomb|Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien|Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
#
#   Eye color Skin color                                  Measurements  \
# 0    yellow    Unknown  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1      blue       blue   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
#
#          Hero          Publisher
# 0      A-Bomb      Marvel Comics
# 1  Abe Sapien  Dark Horse Comics

# %%
hero_df = hero_df.drop(columns = 'Hero|Publisher')
hero_df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#                                    Measurements           Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}  Absorbing Man
#
#            Publisher
# 0      Marvel Comics
# 1  Dark Horse Comics
# 2          DC Comics
# 3      Marvel Comics
# 4      Marvel Comics

# %% [markdown]
# ### Split Measurements

# %%
## slice out a single test measurement
test_measurement = hero_df.loc[1, 'Measurements']
test_measurement
# Out:
# "{'Height': '191.0 cm', 'Weight': '65.0 kg'}"

# %%
## replace ' with " (entire column)
hero_df['Measurements'] = hero_df['Measurements'].str.replace("'", '"')
## apply json.loads
hero_df['Measurements'] = hero_df['Measurements'].apply(json.loads)

# %%
## use .apply pd.Series to convert a dict to columns
hero_df['Measurements'].apply(pd.Series)
# Out:
#        Height    Weight
# 0    203.0 cm  441.0 kg
# 1    191.0 cm   65.0 kg
# 2    185.0 cm   90.0 kg
# 3    203.0 cm  441.0 kg
# 4    193.0 cm  122.0 kg
# ..        ...       ...
# 458  183.0 cm   83.0 kg
# 459  165.0 cm   52.0 kg
# 460   66.0 cm   17.0 kg
# 461  170.0 cm   57.0 kg
# 462  185.0 cm   81.0 kg
#
# [463 rows x 2 columns]

# %%
## Concatenate the 2 new columns and drop the original.
hero_df = pd.concat([hero_df, hero_df['Measurements'].apply(pd.Series)], axis = 1)
hero_df.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color  \
# 0   Male          Human      good    No Hair    yellow    Unknown
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue
#
#                                    Measurements        Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}      A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}  Abe Sapien
#
#            Publisher    Height    Weight
# 0      Marvel Comics  203.0 cm  441.0 kg
# 1  Dark Horse Comics  191.0 cm   65.0 kg

# %%
hero_df = hero_df.drop(columns = 'Measurements')
hero_df.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color        Hero  \
# 0   Male          Human      good    No Hair    yellow    Unknown      A-Bomb
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue  Abe Sapien
#
#            Publisher    Height    Weight
# 0      Marvel Comics  203.0 cm  441.0 kg
# 1  Dark Horse Comics  191.0 cm   65.0 kg

# %%
#fix the weight column
# Make a list of all characters to replace
to_replace = [' kg',]
# run a loop to replace all of the characters in the list at once
for char in to_replace:
    hero_df['Weight'] = hero_df['Weight'].str.replace(char,'',regex=False)

hero_df.head(5)
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher    Height Weight
# 0         A-Bomb      Marvel Comics  203.0 cm  441.0
# 1     Abe Sapien  Dark Horse Comics  191.0 cm   65.0
# 2       Abin Sur          DC Comics  185.0 cm   90.0
# 3    Abomination      Marvel Comics  203.0 cm  441.0
# 4  Absorbing Man      Marvel Comics  193.0 cm  122.0

# %%
hero_df['Weight'].dtypes
# Out:
# dtype('O')

# %%
hero_df['Weight']= hero_df['Weight'].astype(float)

# %%
#fix the height column
# Make a list of all characters to replace
to_replace = [' cm',]
# run a loop to replace all of the characters in the list at once
for char in to_replace:
    hero_df['Height'] = hero_df['Height'].str.replace(char,'',regex=False)

hero_df.head(5)
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher Height  Weight
# 0         A-Bomb      Marvel Comics  203.0   441.0
# 1     Abe Sapien  Dark Horse Comics  191.0    65.0
# 2       Abin Sur          DC Comics  185.0    90.0
# 3    Abomination      Marvel Comics  203.0   441.0
# 4  Absorbing Man      Marvel Comics  193.0   122.0

# %%
hero_df['Height']= hero_df['Height'].astype(float)

# %% [markdown]
# ### One-hot-encode Powers

# %%
powers_df['Powers'] = powers_df['Powers'].str.split(',')
powers_df.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man    [Agility, Super Strength, Stamina, Super Speed]
# 1       A-Bomb  [Accelerated Healing, Durability, Longevity, S...
# 2   Abe Sapien  [Agility, Accelerated Healing, Cold Resistance...
# 3     Abin Sur                               [Lantern Power Ring]
# 4  Abomination  [Accelerated Healing, Intelligence, Super Stre...

# %%
exploded = powers_df.explode('Powers')
exploded[['Powers']].head()
# Out:
#                 Powers
# 0              Agility
# 0       Super Strength
# 0              Stamina
# 0          Super Speed
# 1  Accelerated Healing

# %%
col_to_make = exploded['Powers'].dropna().unique()
col_to_make
# Out:
# array(['Agility', 'Super Strength', 'Stamina', 'Super Speed',
#        'Accelerated Healing', 'Durability', 'Longevity', 'Camouflage',
#        'Self-Sustenance', 'Cold Resistance', 'Underwater breathing',
#        'Marksmanship', 'Weapons Master', 'Intelligence', 'Telepathy',
#        'Immortality', 'Reflexes', 'Enhanced Sight', 'Sub-Mariner',
#        'Lantern Power Ring', 'Invulnerability', 'Animation',
#        'Super Breath', 'Dimensional Awareness', 'Flight', 'Size Changing',
#        'Teleportation', 'Magic', 'Dimensional Travel',
#        'Molecular Manipulation', 'Energy Manipulation', 'Power Cosmic',
#        'Energy Absorption', 'Elemental Transmogrification',
#        'Fire Resistance', 'Natural Armor', 'Heat Resistance',
#        'Matter Absorption', 'Regeneration', 'Stealth', 'Power Suit',
#        'Energy Blasts', 'Energy Beams', 'Heat Generation', 'Danger Sense',
#        'Phasing', 'Force Fields', 'Hypnokinesis', 'Invisibility',
# ...

# %%
for col in col_to_make:
    powers_df[col] = powers_df['Powers'].str.contains(col, regex = False)
powers_df.head()
# Out:
# /var/folders/m6/qy58l3h508n42h5dd2vy0yyr0000gn/T/ipykernel_13653/3733758885.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col, regex = False)
# /var/folders/m6/qy58l3h508n42h5dd2vy0yyr0000gn/T/ipykernel_13653/3733758885.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   powers_df[col] = powers_df['Powers'].str.contains(col, regex = False)
# ...

# %%
powers_df = powers_df.drop(columns=['Powers'])
powers_df.head()
# Out:
#     hero_names  Agility  Super Strength  Stamina  Super Speed  \
# 0      3-D Man     True            True     True         True
# 1       A-Bomb    False            True     True        False
# 2   Abe Sapien     True            True     True        False
# 3     Abin Sur    False           False    False        False
# 4  Abomination    False            True     True         True
#
#    Accelerated Healing  Durability  Longevity  Camouflage  Self-Sustenance  \
# 0                False       False      False       False            False
# 1                 True        True       True        True             True
# 2                 True        True       True       False            False
# 3                False       False      False       False            False
# 4                 True       False      False       False            False
#
#    ...  Weather Control  Omnipresent  Omniscient  Hair Manipulation  \
# 0  ...            False        False       False              False
# ...

# %% [markdown]
# ## Join Datasets

# %%
df = pd.merge(hero_df, powers_df, left_on='Hero', right_on ='hero_names')
df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher  Height  Weight  ... Weather Control  \
# 0         A-Bomb      Marvel Comics   203.0   441.0  ...           False
# 1     Abe Sapien  Dark Horse Comics   191.0    65.0  ...           False
# 2       Abin Sur          DC Comics   185.0    90.0  ...           False
# 3    Abomination      Marvel Comics   203.0   441.0  ...           False
# 4  Absorbing Man      Marvel Comics   193.0   122.0  ...           False
#
#    Omnipresent  Omniscient  Hair Manipulation  Nova Force  Odin Force  \
# ...

# %%
df = df.drop(columns =['hero_names'])

# %% [markdown]
# ## Analysis

# %%
#Compare the average weight of super powers who have Super Speed to those who do not.
df.groupby(['Super Speed'])['Weight'].mean()
# Out:
# Super Speed
# False    101.773585
# True     129.404040
# Name: Weight, dtype: float64

# %%
#What is the average height of heroes for each publisher?
df.groupby(['Publisher'])['Height'].mean()
# Out:
# Publisher
# DC Comics            181.923913
# Dark Horse Comics    176.909091
# George Lucas         159.600000
# Image Comics         211.000000
# Marvel Comics        191.546128
# Shueisha             171.500000
# Star Trek            181.500000
# Team Epic TV         180.750000
# Unknown              178.000000
# Name: Height, dtype: float64
